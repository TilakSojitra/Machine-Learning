# %% [markdown]
# <a href="https://colab.research.google.com/github/TilakSojitra/Machine-Learning/blob/master/ML5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1: Try the algo on Same
#Weather dataset - LabelEncoding of features:and Train test Division 95%-5%

from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier

#Predictor variables
Outlook = ['Rainy', 'Rainy', 'Overcast', 'Sunny', 'Sunny', 'Sunny','Overcast','Rainy', 'Rainy', 'Sunny', 'Rainy','Overcast', 'Overcast','Sunny']
Temperature = ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool','Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild']
Humidity = ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'Normal','High', 'Normal', 'Normal', 'Normal', 'High', 'Normal','High']
Wind = ['False', 'True', 'False', 'False', 'False', 'True', 'True','False', 'False', 'False', 'True', 'True', 'False', 'True']

#Class Label:
Play = ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No','Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']

#creating labelEncoder
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
Outlook_encoded = le.fit_transform(Outlook)
Outlook_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))

# print("Outllok mapping:",Outlook_name_mapping)

Temperature_encoded = le.fit_transform(Temperature)
Temperature_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))

# print("Temperature mapping:",Temperature_name_mapping)

Humidity_encoded = le.fit_transform(Humidity)
Humidity_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
# print("Humidity mapping:",Humidity_name_mapping)

Wind_encoded = le.fit_transform(Wind)
Wind_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
# print("Wind mapping:",Wind_name_mapping)

Play_encoded = le.fit_transform(Play)
Play_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
# print("Play mapping:",Play_name_mapping)

# print("\nWeather:" ,Outlook_encoded)
# print("Temerature:" ,Temperature_encoded)
# print("Humidity:" ,Humidity_encoded)
# print("Wind:" ,Wind_encoded)
# print("Play:" ,Play_encoded)

from sklearn.model_selection import train_test_split

features = tuple(zip(Outlook_encoded,Temperature_encoded,Humidity_encoded,Wind_encoded))
label = Play_encoded

X_train, X_test, y_train, y_test = train_test_split(features,label,test_size=0.05, random_state=0)
# print(X_train, X_test)

#Create a Decision Tree Classifier (using Entropy)
# Train the model using the training sets

from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion="entropy",random_state=0)
model.fit(features,label)

#Predict Output
model.predict([[2,1,0,1]])
# Out:
# array([0])

# %%
#Task 1: Try the algo on Same
#Weather dataset - LabelEncoding of features:and Train test Division 95%-5%

from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier

#Predictor variables
Outlook = ['Rainy', 'Rainy', 'Overcast', 'Sunny', 'Sunny', 'Sunny','Overcast','Rainy', 'Rainy', 'Sunny', 'Rainy','Overcast', 'Overcast','Sunny']
Temperature = ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool','Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild']
Humidity = ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'Normal','High', 'Normal', 'Normal', 'Normal', 'High', 'Normal','High']
Wind = ['False', 'True', 'False', 'False', 'False', 'True', 'True','False', 'False', 'False', 'True', 'True', 'False', 'True']

#Class Label:
Play = ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No','Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']

#creating labelEncoder
le = preprocessing.LabelEncoder()

# Converting string labels into numbers.
Outlook_encoded = le.fit_transform(Outlook)
Outlook_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))

print("Outllok mapping:",Outlook_name_mapping)

Temperature_encoded = le.fit_transform(Temperature)
Temperature_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))

print("Temperature mapping:",Temperature_name_mapping)

Humidity_encoded = le.fit_transform(Humidity)
Humidity_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Humidity mapping:",Humidity_name_mapping)

Wind_encoded = le.fit_transform(Wind)
Wind_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Wind mapping:",Wind_name_mapping)

Play_encoded = le.fit_transform(Play)
Play_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print("Play mapping:",Play_name_mapping)

# print("\nWeather:" ,Outlook_encoded)
# print("Temerature:" ,Temperature_encoded)
# print("Humidity:" ,Humidity_encoded)
# print("Wind:" ,Wind_encoded)
# print("Play:" ,Play_encoded)

from sklearn.model_selection import train_test_split

features = tuple(zip(Outlook_encoded,Temperature_encoded,Humidity_encoded,Wind_encoded))
label = Play_encoded

X_train, X_test, y_train, y_test = train_test_split(features,label,test_size=0.75, random_state=133)
# print(X_train, X_test)

model = DecisionTreeClassifier(criterion="entropy",random_state=0)
model.fit(features,label)

#Predict Output
model.predict([[2,1,0,1]])

# 1. What will be the value of Play, if Outlook is ’Rainy’, Temperature is ’Mild’, Humidity =’Normal’, and Wind = ’False’?
print(model.predict([[1,2,1,0]]))

# 2. What will be the value of Play, if Outlook is ’Sunny’, Temeprature is ’Cool’, Humidity =’High’, and Wind = ’True’?
print(model.predict([[2,0,0,1]]))

# 3. Plot the decision tree generated by the model for weather dataset. What were the values of criterion, max_depth during model generation.

import matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize=(15,10))
a = tree.plot_tree(model, rounded=True, filled=True, fontsize=14)
plt.show()

# criterian:- "entropy" , max_depth:- 4

# 4. Accuracy , precision and recall of both Models

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

pred = model.predict(X_test)
print(accuracy_score(y_test,pred)) 
print(precision_score(y_test,pred)) 
print(recall_score(y_test,pred))
# 1.0
# 1.0
# 1.0

# 6.Train weather dataset using Decision Tree Classifier with max_depth of the tree =2. Find out accuracy, precision and recall of the trained model.

model1 = DecisionTreeClassifier(criterion="entropy",max_depth=2,random_state=133)
model1.fit(features,label)

plt.figure(figsize=(15,10))
a = tree.plot_tree(model1, rounded=True, filled=True, fontsize=14)
plt.show()

pred = model1.predict(X_test)
print(accuracy_score(y_test,pred))
print(precision_score(y_test,pred))
print(recall_score(y_test,pred))
# 0.8181818181818182
# 0.8571428571428571
# 0.8571428571428571
# Out:
# Outllok mapping: {'Overcast': 0, 'Rainy': 1, 'Sunny': 2}
# Temperature mapping: {'Cool': 0, 'Hot': 1, 'Mild': 2}
# Humidity mapping: {'High': 0, 'Normal': 1}
# Wind mapping: {'False': 0, 'True': 1}
# Play mapping: {'No': 0, 'Yes': 1}
# [1]
# [0]
# 1.0
# 1.0
# 1.0
# 0.8181818181818182
# 0.8571428571428571
# 0.8571428571428571

# %%
#Task 2: Apply algorithm on wine dataset - LabelEncoding of features: and Train test Division 66%-34%

from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets

wine = datasets.load_wine()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(wine.data,wine.target,test_size=0.34, random_state=133)

model = DecisionTreeClassifier(criterion="entropy",random_state=133)
model.fit(wine.data,wine.target)

#Predict Output
model.predict([wine.data[100]])

from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

pred = model.predict(X_test)
print(accuracy_score(y_test,pred))
print(precision_score(y_test,pred,average=None))
print(recall_score(y_test,pred,average=None))
# Out:
# 1.0
# [1. 1. 1.]
# [1. 1. 1.]

# %%
# 7. Implement the Decision Tree classifier on Iris dataset and find the ccp_alpha values associated with the decision tree generated.

from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets

iros = datasets.load_iris()

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(wine.data,wine.target,test_size=0.34, random_state=133)

clf = DecisionTreeClassifier(random_state=133)
path = clf.cost_complexity_pruning_path(X_train,y_train)
ccp_alphas = path.ccp_alphas

print(ccp_alphas)
# [0.         0.01664417 0.03247863 0.04733728 0.28459193]
# Out:
# [0.         0.01664417 0.03247863 0.04733728 0.28459193]
